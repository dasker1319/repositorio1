# %%
print("digite su primer numero")
num1=float(input("ing"))
print("digite su segundo numero")
num2=float(input("ing"))
x1=num1+num2
x2=num1-num2
x3=num1*num2
x4=num1/num2
print(x1,   x2,   x3,   x4)
# Out:
# digite su primer numero
