# %%
S=set([5,4,8,8,1])
print(S)
print(type(S))
# Out:
# {8, 1, 4, 5}
# <class 'set'>

# %%
s={5,6,4,8,8,1}
print(s)
print(type)
# Out:
# {1, 4, 5, 6, 8}
# <class 'type'>

# %%
lista=["Perú","Argentina"]
s=set(["Mexico","Esapaña", lista])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1773617459.py in <cell line: 0>()
#       1 lista=["Perú","Argentina"]
# ----> 2 s=set(["Mexico","Esapaña", lista])
#
# TypeError: unhashable type: 'list'

# %%
lista=["Perú","Argentina"]
lista.append("mexico")
lista.append("españa")
print(lista)
# Out:
# ['Perú', 'Argentina', 'mexico', 'españa']

# %%
s=set([5,6,7,8])
for ss in s:
  print(ss)
# Out:
# 8
# 5
# 6
# 7

# %%
s=set([1,2,2,3,4])
print(len(s))
# Out:
# 4

# %%
s=set(["paka","darian",1,2,2,3,4])
print(len(s))
# Out:
# 6

# %%
s=set(["guitarra","Bajo"])
print("guitarra" in s)
# Out:
# True

# %%
s=set(["guitarra","Bajo"])
print("millos" in s)
# Out:
# False

# %%
s1=set([1,2,3])
s2=set([3,4,5])
print(s1| s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
l=set([1,2])
l.add(3)
print(l)
# Out:
# {1, 2, 3}

# %%
s=set([1,2])
s.remove(2)
print(s)
# Out:
# {1}

# %%
s=set([1,2])
s.discard(3)
print(s)
# Out:
# {1, 2}

# %%
s=set([1,2])
s.pop()
print(s)
# Out:
# {2}

# %%
s1={1,2,3}
s2={3,4,5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
s1={1,2,3}
s2={3,4,5}
print(s1.intersection(s2))
# Out:
# {3}

# %%
EquipoFrontend={'HTML', 'CSS', 'JavaScript', 'React' }
EquipoBackend={'Python', 'SQL', 'JavaScript', 'Django'}
print(EquipoFrontend.difference(EquipoBackend))
# Out:
# {'CSS', 'HTML', 'React'}

# %%
EquipoFrontend={'HTML', 'CSS', 'JavaScript', 'React' }
EquipoBackend={'Python', 'SQL', 'JavaScript', 'Django'}
print(EquipoFrontend.union(EquipoBackend))
# Out:
# {'CSS', 'Django', 'Python', 'SQL', 'JavaScript', 'HTML', 'React'}

# %%
EquipoFrontend={'HTML', 'CSS', 'JavaScript', 'React' }
EquipoBackend={'Python', 'SQL', 'JavaScript', 'Django'}
print(EquipoFrontend.intersection(EquipoBackend))
# Out:
# {'JavaScript'}
