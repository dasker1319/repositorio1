# %%
d1 = {
    "Nombre": "Sara",
    "Edad": 27,
    "Documento": 1003882
}
print(d1)
# Out:
# {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %%
d1 = {
    "Nombre": "paka",
    "Edad": 17,
    "Documento": 1012357850
}
print(d1)
# Out:
# {'Nombre': 'paka', 'Edad': 17, 'Documento': 1012357850}

# %%
d2 = dict([
    ('Nombre', 'Sara'),
    ('Edad', 27),
    ('Documento', 1003882),
])
print(d2)
# Out:
# {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %%
d3 = dict(Nombre='Sara', Edad=27, Documento=1003882)
print(d3)
# Out:
# {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %%
print(d1['Nombre'])
print(d1.get('Nombre'))
print(d1['Edad'])
print(d1.get('Edad'))
print(d1['Documento'])
print(d1.get('Documento'))
# Out:
# paka
# paka
# 17
# 17
# 1012357850
# 1012357850

# %%
d1['Nombre'] = 'Laura'
print(d1)
# Out:
# {'Nombre': 'Laura', 'Edad': 17, 'Documento': 1012357850}

# %%
d1['direccion']="calle 123"
print(d1)
# Out:
# {'Nombre': 'Laura', 'Edad': 17, 'Documento': 1012357850, 'direccion': 'calle 123'}

# %%
# Imprime los key del diccionario
for x in d1:
    print(x)
#Nombre
#Edad
#Documento
#Direccion
# Out:
# Nombre
# Edad
# Documento
# direccion

# %%
# Imprime los value del diccionario
for x in d1:
    print(d1[x])
#Laura
#27
#1003882
#Calle 123
# Out:
# Laura
# 17
# 1012357850
# calle 123

# %%
for x, y in d1.items():
    print(x, y)
# Out:
# Nombre Laura
# Edad 17
# Documento 1012357850
# direccion calle 123

# %%
anidado1 = {"a": 1, "b": 2}
anidado2 = {"a": 1, "b": 2}
d = {
    "anidado1": anidado1,
    "anidado2": anidado2
}

print(d)
# {'anidado1': {'a': 1, 'b': 2}, 'anidado2': {'a': 1, 'b': 2}}
# Out:
# {'anidado1': {'a': 1, 'b': 2}, 'anidado2': {'a': 1, 'b': 2}}

# %%
d = {'a': 1, 'b': 2}
d.clear()
print(d)  # {}
# Out:
# {}

# %%
d = {'a': 1, 'b': 2}
print(d.get('a'))        # 1
print(d.get('z', 'No encontrado'))  # No encontrado
# Out:
# 1
# No encontrado

# %%
d = {'a': 1, 'b': 2}
it=d.items()
print(it)
print(list(it))
print(list(it)[0][0])
# Out:
# dict_items([('a', 1), ('b', 2)])
# [('a', 1), ('b', 2)]
# a

# %%
d = {'a': 1, 'b': 2}
k=d.keys()
print(k)
print(list(k))
# Out:
# dict_keys(['a', 'b'])
# ['a', 'b']

# %%
d={'a': 1, 'b': 2}
print(list(d.values()))
# Out:
# [1, 2]

# %%
d={'a': 1, 'b': 2}
d.pop('a')
print(d)
# Out:
# {'b': 2}

# %%
d={'a': 1, 'b': 2}
d.pop('c',-1)
print(d)
# Out:
# {'a': 1, 'b': 2}

# %%
d={'a': 1, 'b': 2}
d.popitem()
print(d)
# Out:
# {'a': 1}

# %%
d1={'a': 1, 'b': 2}
d2={'a': 0, 'b': 400}
d1.update(d2)
print(d1)
# Out:
# {'a': 0, 'b': 400}
