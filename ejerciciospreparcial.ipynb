# %%
mylist=["Mexico","Canada","Holanda"]
print(mylist)
for item in mylist:
  print(item)
# Out:
# ['Mexico', 'Canada', 'Holanda']
# Mexico
# Canada
# Holanda

# %%
mylist=["rojo","azul","morado"]
listin=[10,20,30]
print(mylist)
print(listin)
for item in mylist:
  print(item)
for item in listin:
  print(item)
# Out:
# ['rojo', 'azul', 'morado']
# [10, 20, 30]
# rojo
# azul
# morado
# 10
# 20
# 30

# %%
animales=["gato","perro","loro","pez","caballo"]
print(animales[0])
print(animales[4])
print(animales[2])
print(animales[1])
print(animales[-2])
# Out:
# gato
# caballo
# loro
# perro
# pez

# %%
frutas=[]
frutas.append("manzana")
frutas.append("banana")
frutas.append("uva")
print(frutas)
# Out:
# ['manzana', 'banana', 'uva']

# %%
animales=[]
animales=animales+["gato","perro","loro"]
print(animales)
# Out:
# ['gato', 'perro', 'loro']

# %%
cosas=["mesa",10,"silla",20,"puerta"]
cosas.pop(1)
cosas.pop(3)
cosas.pop(0)
print(cosas)
# Out:
# ['silla', 20]

# %%
numeros=[1,2,3,4,5,2]
numeros.remove(2)
print(numeros)
# Out:
# [1, 3, 4, 5, 2]
