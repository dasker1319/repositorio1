# %%
#ejercicio1
# Almacenamos la cadena "¡Hola Mundo!" en una variable
mensaje = "¡Hola Mundo!"

# Mostramos el contenido de la variable
print(mensaje)
# Out:
# ¡Hola Mundo!

# %%
#ejercicio2
# Pedimos el nombre del usuario
nombre = input("¿Cuál es tu nombre? ")

# Mostramos el saludo con el nombre del usuario
print(f"¡Hola {nombre}!")
