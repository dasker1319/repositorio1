# %%
from collections import deque

cola = deque(["A", "B", "C"])
print("Cola inicial:", cola)

cola.append("D")
print("Cola actual:", cola)

primero = cola.popleft()  # #popleft() desencolar desde el inicio
print("Se eliminó:", primero)
print("Cola después de desencolar:", cola)
# Out:
# Cola inicial: deque(['A', 'B', 'C'])
# Cola actual: deque(['A', 'B', 'C', 'D'])
# Se eliminó: A
# Cola después de desencolar: deque(['B', 'C', 'D'])

# %%
from collections import deque

cola_doble = deque(["X", "Y"])
cola_doble.appendleft("A")
cola_doble.append("B")

print("Cola doble:", cola_doble)

cola_doble.pop()      # #pop() desencolar desde el final.
cola_doble.popleft()  # #popleft() desencolar desde el inicio.

print("Cola doble después:", cola_doble)
# Out:
# Cola doble: deque(['A', 'X', 'Y', 'B'])
# Cola doble después: deque(['X', 'Y'])

# %%
from queue import PriorityQueue

cola = PriorityQueue()

# Cada elemento es una tupla: (prioridad, valor)
cola.put((1, 'Paciente grave'))
cola.put((3, 'Paciente leve'))
cola.put((2, 'Paciente medio'))

# Desencolar respeta las prioridades, no el orden de llegada
print("Atendido:", cola.get())  # (1, 'Paciente grave')
print("Atendido:", cola.get())  # (2, 'Paciente medio')
print("Atendido:", cola.get())  # (3, 'Paciente leve')
# Out:
# Atendido: (1, 'Paciente grave')
# Atendido: (2, 'Paciente medio')
# Atendido: (3, 'Paciente leve')

# %%
from collections import deque

jugadores = deque(["Carolina", "Darian", "Jefry", "Adrian"])

for i in range(10):
    turno = jugadores.popleft()
    print("Turno de:", turno)
    jugadores.append(turno)

print("Cola final:", jugadores)
# Out:
# Turno de: Carolina
# Turno de: Darian
# Turno de: Jefry
# Turno de: Adrian
# Turno de: Carolina
# Turno de: Darian
# Turno de: Jefry
# Turno de: Adrian
# Turno de: Carolina
# Turno de: Darian
# Cola final: deque(['Jefry', 'Adrian', 'Carolina', 'Darian'])
