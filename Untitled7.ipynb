# %%
usuarios_registrados = ["ana_dev", "luis_ux", "carlos_pm"]
# conjunto para verificación rápida de duplicados
usuarios_unicos = set(usuarios_registrados)
# Simular llegada de un nuevo usuario repetido
nuevo_usuario = "luis_ux"
if nuevo_usuario in usuarios_unicos:
    print("El usuario", nuevo_usuario, "ya está registrado.")
else:
    usuarios_registrados.append(nuevo_usuario)
    usuarios_unicos.add(nuevo_usuario)
# Simular llegada de un nuevo usuario distinto
nuevo_usuario = "sofia_qa"
if nuevo_usuario in usuarios_unicos:
    print("El usuario", nuevo_usuario, "ya está registrado.")
else:
    usuarios_registrados.append(nuevo_usuario)
    usuarios_unicos.add(nuevo_usuario)
# Mostrar resultados finales
print("\nLista final de usuarios registrados (ordenada):")
print(usuarios_registrados)
print("\nConjunto de usuarios únicos:")
print(usuarios_unicos)
# Out:
# El usuario luis_ux ya está registrado.
#
# Lista final de usuarios registrados (ordenada):
# ['ana_dev', 'luis_ux', 'carlos_pm', 'sofia_qa']
#
# Conjunto de usuarios únicos:
# {'luis_ux', 'ana_dev', 'sofia_qa', 'carlos_pm'}

# %%
# ejercicio2
ventas_precios = [15.50, 20.00, 5.75, 15.50, 30.00]
productos_vendidos = ["cafe", "torta", "galleta", "cafe", "almuerzo"]
#Calcular ingresos totales
ingresos_totales = sum(ventas_precios)
#conjunto con productos únicos
productos_unicos = set(productos_vendidos)
print("Ingresos totales:", ingresos_totales)
print("Número de productos únicos vendidos:", len(productos_unicos))
# Out:
# Ingresos totales: 86.75
# Número de productos únicos vendidos: 4

# %%
# ejericio3
tareas = ["Enviar reporte", "Revisar correos"]
# Añadir nueva tarea
nueva_tarea = "Llamar al cliente"
tareas.append(nueva_tarea)
# Mostrar lista actualizada
print("Lista de tareas actualizada:", tareas)
# Marcar la primera como completada
tareas[0] = tareas[0] + " (Completada)"
# Mostrar lista final
print("Lista final de tareas:", tareas)
# Out:
# Lista de tareas actualizada: ['Enviar reporte', 'Revisar correos', 'Llamar al cliente']
# Lista final de tareas: ['Enviar reporte (Completada)', 'Revisar correos', 'Llamar al cliente']

# %%
#ejercicio 4
# Datos de los ids de personas que ya ingresaron
asistentes_ingresados = {"ID_1122", "ID_3344"}
#se crea la  una variable llamada persona_llegando que representa el ID de la persona que acaba de llegar.
persona_llegando = "ID_5566"
#nueva a ingresar entonces se agrega a ese conjunto con add()
if persona_llegando in asistentes_ingresados:
    print("Tu ya ingresaste.")
else:
    asistentes_ingresados.add(persona_llegando)
    print("Hola! eres bienvenido aqui")
# Aca se hace el ejemplo de que llego la persona... "ID_1122"
persona_llegando = "ID_1122"
if persona_llegando in asistentes_ingresados:
    print("Tu ya ingresaste.")
else:
    asistentes_ingresados.add(persona_llegando)
    print("Hola! eres bienvenido aqui ")

# Aqui muestro cuales son los que ingresaron finalmente
print("Asistentes totales que finalmente ingresaron:", asistentes_ingresados)
# Out:
# Hola! eres bienvenido aqui
# Tu ya ingresaste.
# Asistentes totales que finalmente ingresaron: {'ID_5566', 'ID_3344', 'ID_1122'}

# %%
# ejercicio5
# Lista de notas
calificaciones = [3.5, 4.0, 5.0, 2.5, 3.5, 4.0, 4.8]
# Calcular el promedio
promedio = sum(calificaciones) / len(calificaciones)
# Crear conjunto de notas únicas
notas_unicas = set(calificaciones)
# Mostrar resultados
print("Promedio de las calificaciones:", round(promedio, 2))
print("Notas únicas obtenidas:", notas_unicas)
# Out:
# Promedio de las calificaciones: 3.9
# Notas únicas obtenidas: {2.5, 3.5, 4.8, 4.0, 5.0}

# %%
# ejercicio6
# Tallas
tallas_disponibles = ["S", "M", "L", "M"]
# Crear conjunto sin duplicados
tallas_unicas = set(tallas_disponibles)
# Nueva talla que llega
nueva_talla = "XL"
tallas_unicas.add(nueva_talla)
# Intentar añadir nuevamente una talla que ya existe
nueva_talla = "S"
tallas_unicas.add(nueva_talla)
# Mostrar conjunto final
print("Tallas únicas disponibles:", tallas_unicas)
# Out:
# Tallas únicas disponibles: {'M', 'S', 'L', 'XL'}

# %%
#ejercicio7 # ciudades amigo y mias
mis_sugerencias = ["París", "Roma", "Berlín"] sugerencias_amigo = ["Londres", "Roma", "Praga"]
# conjuntos a partir de las listas
mis_set = set(mis_sugerencias)
amigo_set = set(sugerencias_amigo)
# Unir ambas sugerencias en un solo conjunto
destinos_finales = mis_set.union(amigo_set)
print("Destinos finales sin repeticiones:", destinos_finales)# Mostrar resultados
print("Cantidad total de destinos únicos:", len(destinos_finales))# Mostrar resultados
# Out:
# Destinos finales sin repeticiones: {'Londres', 'Berlín', 'París', 'Roma', 'Praga'}
# Cantidad total de destinos únicos: 5

# %%
#ejercicio8 # calificaciones
respuestas = [5, 4, 3, 5, 5, 2, 4, 5, 1, 5]
contador_max_satisfaccion = 0 # Contador de personas muy satisfechas
# Recorrer respuestas y contar cuántas son iguales a 5
for r in respuestas:
    if r == 5:
        contador_max_satisfaccion += 1
respuestas_unicas = set(respuestas)# Conjunto de respuestas únicas
# Mostrar resultados
print("Total de personas muy satisfechas (respuesta 5):", contador_max_satisfaccion)
print("Opciones de respuesta marcadas:", respuestas_unicas)
# Out:
# Total de personas muy satisfechas (respuesta 5): 5
# Opciones de respuesta marcadas: {1, 2, 3, 4, 5}

# %%
# ejercicio9 #ingredientes
ingredientes_masa = ["harina", "mantequilla", "agua", "sal"] ingredientes_relleno = ["queso", "espinaca", "huevo", "sal"]
# Combinar ambas listas
ingredientes_combinados = ingredientes_masa + ingredientes_relleno
# Eliminar duplicados con un conjunto
lista_compras = set(ingredientes_combinados)
print("Lista de compras final:", lista_compras)# Mostrar lista de compras final
# Out:
# Lista de compras final: {'queso', 'sal', 'harina', 'huevo', 'mantequilla', 'espinaca', 'agua'}

# %%
# ejercicio10 #correos
spam_emails = {"spam1@example.com", "ofertas@mal.com", "dudoso@mail.net"}
correo_entrante = "usuario.normal@email.com"# Primer correo entrante
if correo_entrante in spam_emails:
    print("Alerta de SPAM:", correo_entrante)
else:
    print("Correo seguro:", correo_entrante)
# Segundo correo entrante
correo_entrante = "ofertas@mal.com"
if correo_entrante in spam_emails:
    print("Alerta de SPAM:", correo_entrante)
else:
    print("Correo seguro:", correo_entrante)
# Registro de verificaciones
log_verificaciones = ["usuario.normal@email.com", "ofertas@mal.com"]
# Mostrar log final
print("Log de verificaciones:", log_verificaciones)
# Out:
# Correo seguro: usuario.normal@email.com
# Alerta de SPAM: ofertas@mal.com
# Log de verificaciones: ['usuario.normal@email.com', 'ofertas@mal.com']
