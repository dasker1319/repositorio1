# %%
numeros=[]
numeros=numeros+[10,5,3]
print(numeros)
# Out:
# [10, 5, 3]

# %%
palabras=['hola', 5,'adios', 3,'comida']
palabras.pop(-2)
palabras.pop(0)
palabras.pop(-1)
print(palabras)
# Out:
# [5, 'adios']

# %%
palabras =['hola', 'hello', 'hello','ola']#agregando elementos a la lista

palabras.remove('hello')#remueve un elemento especifico de la lista
palabras.remove('hello')
print(palabras)#imprime las pqalabras restantes de la lista
# Out:
# ['hola', 'ola']

# %%
personas=["jose","maria","josefina"]
