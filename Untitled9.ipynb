# %%
import os

os.mkdir("carpeta1")

print(os.listdir("."))
# Out:
# ['.config', 'nueva carpeta', 'carpeta1', 'sample_data']

# %%
from pathlib import Path

Path("nueva carpeta").mkdir()
print(list(Path(".").iterdir()))
# Out:
# [PosixPath('.config'), PosixPath('nueva carpeta'), PosixPath('sample_data')]
